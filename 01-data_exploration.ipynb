# %%
import pandas as pd
import numpy as np 
from statsbombpy import sb

# %%
competitions = sb.competitions()
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
competitions['competition_name'].value_counts()
# Out:
# competition_name
# Champions League           18
# La Liga                    18
# FIFA World Cup              8
# Copa del Rey                3
# Ligue 1                     3
# FA Women's Super League     3
# Liga Profesional            2
# 1. Bundesliga               2
# Premier League              2
# Women's World Cup           2
# Serie A                     2
# African Cup of Nations      1
# Major League Soccer         1
# Indian Super league         1
# FIFA U20 World Cup          1
# NWSL                        1
# North American League       1
# UEFA Euro                   1
# UEFA Europa League          1
# UEFA Women's Euro           1
# Name: count, dtype: int64

# %%
laliga = competitions[competitions.competition_name =='La Liga']

# %%
laliga
# Out:
#     competition_id  season_id country_name competition_name  \
# 37              11         90        Spain          La Liga
# 38              11         42        Spain          La Liga
# 39              11          4        Spain          La Liga
# 40              11          1        Spain          La Liga
# 41              11          2        Spain          La Liga
# 42              11         27        Spain          La Liga
# 43              11         26        Spain          La Liga
# 44              11         25        Spain          La Liga
# 45              11         24        Spain          La Liga
# 46              11         23        Spain          La Liga
# 47              11         22        Spain          La Liga
# 48              11         21        Spain          La Liga
# 49              11         41        Spain          La Liga
# 50              11         40        Spain          La Liga
# 51              11         39        Spain          La Liga
# ...

# %%
sb.matches(competition_id=11, season_id=27)
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#      match_id  match_date      kick_off      competition     season  \
# 0     3825848  2015-09-23  20:00:00.000  Spain - La Liga  2015/2016
# 1     3825895  2015-09-23  22:00:00.000  Spain - La Liga  2015/2016
# 2     3825894  2016-05-01  18:15:00.000  Spain - La Liga  2015/2016
# 3     3825855  2016-05-02  20:30:00.000  Spain - La Liga  2015/2016
# 4     3825908  2016-05-15  19:00:00.000  Spain - La Liga  2015/2016
# ..        ...         ...           ...              ...        ...
# 375    266467  2015-09-23  20:00:00.000  Spain - La Liga  2015/2016
# 376    267273  2016-02-20  17:00:00.000  Spain - La Liga  2015/2016
# 377    266490  2015-09-20  20:30:00.000  Spain - La Liga  2015/2016
# 378    266254  2016-02-14  21:30:00.000  Spain - La Liga  2015/2016
# ...

# %%
for season_id in competitions[competitions.competition_name =='La Liga']['season_id'].unique():
    matches = sb.matches(competition_id=11, season_id=season_id)
    print(season_id, len(matches))
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# 90 35
# 42 33
# /home/codespace/.python/current/lib/python3.10/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# 4 34
# 1 36
# /home/codespace/.python/current/lib/python3.10/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# ...

# %%
sb.matches(competition_id=11, season_id=27)
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#      match_id  match_date      kick_off      competition     season  \
# 0     3825848  2015-09-23  20:00:00.000  Spain - La Liga  2015/2016
# 1     3825895  2015-09-23  22:00:00.000  Spain - La Liga  2015/2016
# 2     3825894  2016-05-01  18:15:00.000  Spain - La Liga  2015/2016
# 3     3825855  2016-05-02  20:30:00.000  Spain - La Liga  2015/2016
# 4     3825908  2016-05-15  19:00:00.000  Spain - La Liga  2015/2016
# ..        ...         ...           ...              ...        ...
# 375    266467  2015-09-23  20:00:00.000  Spain - La Liga  2015/2016
# 376    267273  2016-02-20  17:00:00.000  Spain - La Liga  2015/2016
# 377    266490  2015-09-20  20:30:00.000  Spain - La Liga  2015/2016
# 378    266254  2016-02-14  21:30:00.000  Spain - La Liga  2015/2016
# ...

# %%
sb.events(match_id = 3825894).columns
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Index(['50_50', 'bad_behaviour_card', 'ball_receipt_outcome',
#        'ball_recovery_recovery_failure', 'block_deflection',
#        'carry_end_location', 'clearance_aerial_won', 'clearance_body_part',
#        'clearance_head', 'clearance_left_foot', 'clearance_other',
#        'clearance_right_foot', 'counterpress', 'dribble_nutmeg',
#        'dribble_outcome', 'dribble_overrun', 'duel_outcome', 'duel_type',
#        'duration', 'foul_committed_advantage', 'foul_committed_card',
#        'foul_won_advantage', 'foul_won_defensive', 'goalkeeper_body_part',
#        'goalkeeper_end_location', 'goalkeeper_outcome', 'goalkeeper_position',
#        'goalkeeper_technique', 'goalkeeper_type', 'id', 'index',
#        'interception_outcome', 'location', 'match_id', 'minute',
# ...

# %%
sb.events(match_id = 3825894)['50_50']
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 3178    NaN
# 3179    NaN
# 3180    NaN
# 3181    NaN
# 3182    NaN
# Name: 50_50, Length: 3183, dtype: object
