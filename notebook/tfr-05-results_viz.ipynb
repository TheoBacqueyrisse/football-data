# %%
import pandas as pd
import os
import math

# with open(os.path.join(os.pardir,'data','results','overall_improv.txt'), 'r') as f:
#     overall_improv_list = [float(line.strip()) for line in f.readlines()]

# with open(os.path.join(os.pardir,'data','results','overall_fitness.txt'), 'r') as f: 
#     overall_fitness_list = [float(line.strip()) for line in f.readlines()]


# base_xg = [f / (1 + (i / 100))for f, i in zip(overall_fitness_list, overall_improv_list)]

data_path = os.path.join(os.pardir,'data', 'processed', 'clean_action_data.csv')

# def complete_list(lst):
#     diff = len(df) - len(lst)

#     # add None to the list
#     lst.extend([None] * diff)

#     return lst

# df['pred_base_xg'] = complete_list(base_xg)
# df['pred_improved_xg'] = complete_list(overall_fitness_list)
# df['pctge_improvement'] = complete_list(overall_improv_list)

df = pd.read_csv(data_path)

overall_improv_list = list(filter(lambda x: not math.isnan(x), df['pctge_improvement'].to_list()))
overall_fitness_list = list(filter(lambda x: not math.isnan(x), df['pred_improved_xg'].to_list()))
overall_basexg = list(filter(lambda x: not math.isnan(x), df['pred_base_xg'].to_list()))
# df.to_csv('..\\data\\processed\\clean_action_data.csv', index = False)

# %%
import matplotlib.pyplot as plt
# Create a plot
plt.figure(figsize=(10, 6))

# Plot overall_improv_list against overall_fitness_list
plt.scatter(overall_basexg, overall_improv_list, marker='o', linestyle='-', color='b')

# Add labels and title
plt.xlabel('Base xG')
plt.ylabel('Improvement %')
plt.title('Base xG VS Improvement (%)')

# Optionally, add gridlines
plt.grid(True)

# Show the plot
plt.show()

# %%
data_path = os.path.join(os.pardir,'data', 'processed', 'clean_action_data_glob.csv')

df = pd.read_csv(data_path)

# %%
df['pred_base_xg'] = None
df['pctge_improvement'] = None
df['pctge_improvement'] = None

# %%
df.to_csv(data_path, index = False)

# %%
0%0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 0%0
#
# ZeroDivisionError: integer division or modulo by zero
